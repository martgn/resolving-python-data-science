# %% [markdown]
# <font size="+5">#03 | Machine Learning & Linear Regression</font>

# %% [markdown]
# - Subscribe to my [Blog ↗](https://blog.pythonassembly.com/)
# - Let's keep in touch on [LinkedIn ↗](www.linkedin.com/in/jsulopz) 😄

# %% [markdown]
# # Discipline to Search Solutions in Google

# %% [markdown]
# > Apply the following steps when **looking for solutions in Google**:
# >
# > 1. **Necesity**: How to load an Excel in Python?
# > 2. **Search in Google**: by keywords
# >   - `load excel python`
# >   - ~~how to load excel in python~~
# > 3. **Solution**: What's the `function()` that loads an Excel in Python?
# >   - A Function to Programming is what the Atom to Phisics.
# >   - Every time you want to do something in programming
# >   - **You will need a `function()`** to make it
# >   - Theferore, you must **detect parenthesis `()`**
# >   - Out of all the words that you see in a website
# >   - Because they indicate the presence of a `function()`.

# %% [markdown]
# # Load the Data

# %% [markdown]
# > - Simply execute the following lines of code to load the data.
# > - This dataset contains **statistics about Car Accidents** (columns)
# > - In each one of **USA States** (rows)

# %% [markdown]
# https://www.kaggle.com/fivethirtyeight/fivethirtyeight-bad-drivers-dataset/

# %%
import seaborn as sns

df = sns.load_dataset(name='car_crashes', index_col='abbrev')
df.sample(10)
# Out:
#         total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# abbrev
# LA       20.5     7.175    6.765          14.965       20.090      1281.55
# NV       14.7     5.439    4.704          13.965       14.553      1029.87
# MI       14.1     3.384    3.948          13.395       10.857      1110.61
# OK       19.9     6.368    5.771          18.308       18.706       881.51
# MT       21.4     8.346    9.416          17.976       18.190       816.21
# SC       23.9     9.082    9.799          22.944       19.359       858.97
# WI       13.8     4.968    4.554           5.382       11.592       670.31
# NH       11.6     4.060    3.480          10.092        9.628       746.54
# CT       10.8     4.968    3.888           9.396        8.856      1068.73
# UT       11.3     4.859    1.808           9.944       10.848       809.38
#
#         ins_losses
# abbrev
# LA          194.78
# NV          138.71
# MI          152.26
# OK          178.86
# MT           85.15
# SC          116.29
# WI          106.62
# NH          120.21
# CT          167.02
# UT          109.48

# %% [markdown]
# # Machine Learning, what does it mean?

# %% [markdown]
# > - The Machine Learns...
# >
# > But, **what does it learn?**

# %%
# %%HTML
# <blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">Machine Learning, what does it mean? ⏯<br><br>· The machine learns...<br><br>Ha ha, not funny! 🤨 What does it learn?<br><br>· A mathematical equation. For example: <a href="https://t.co/sjtq9F2pq7">pic.twitter.com/sjtq9F2pq7</a></p>&mdash; Jesús López (@sotastica) <a href="https://twitter.com/sotastica/status/1449735653328031745?ref_src=twsrc%5Etfw">October 17, 2021</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# Out:
# <blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">Machine Learning, what does it mean? ⏯<br><br>· The machine learns...<br><br>Ha ha, not funny! 🤨 What does it learn?<br><br>· A mathematical equation. For example: <a href="https://t.co/sjtq9F2pq7">pic.twitter.com/sjtq9F2pq7</a></p>&mdash; Jesús López (@sotastica) <a href="https://twitter.com/sotastica/status/1449735653328031745?ref_src=twsrc%5Etfw">October 17, 2021</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>

# %% [markdown]
# # How does the Machine Learn?

# %% [markdown]
# ## In a Linear Regression

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Ht3rYS-JilE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Ht3rYS-JilE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## In a Neural Network

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/IHZwWFHWa-w?start=36" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/IHZwWFHWa-w?start=36" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# A Practical Example → [Tesla Autopilot](https://www.tesla.com/AI)

# %% [markdown]
# An Example where It Fails → [Tesla Confuses Moon with Semaphore](https://twitter.com/Carnage4Life/status/1418920100086784000?s=20)

# %% [markdown]
# # `LinearRegression()` Model in Python

# %% [markdown]
# ## Build the Model

# %% [markdown]
# > 1. **Necesity**: Build Model
# > 2. **Google**: How do you search for the solution?
# > 3. **Solution**: Find the `function()` that makes it happen

# %% [markdown]
# **Code Thinking**
#
# > Which function computes the Model?
# > - `fit()`
# >
# > How could can you **reach the `fit()` function in Python**?

# %%
df.mean()
# Out:
# total              15.790196
# speeding            4.998196
# alcohol             4.886784
# not_distracted     13.573176
# no_previous        14.004882
# ins_premium       886.957647
# ins_losses        134.493137
# dtype: float64

# %%
import pandas as pd

# %%
fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2e8ead0159f0> in <module>
# ----> 1 fit()
#
# NameError: name 'fit' is not defined

# %%
sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-217cace8f485> in <module>
# ----> 1 sum()
#
# TypeError: sum() takes at least 1 positional argument (0 given)

# %%
model.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d3dc977168f5> in <module>
# ----> 1 model.fit(x, y)
#
# NameError: name 'model' is not defined

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': False,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False}

# %%
df.__dict__
# Out:
# {'_is_copy': None,
#  '_mgr': BlockManager
#  Items: Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#         'ins_premium', 'ins_losses'],
#        dtype='object')
#  Axis 1: Index(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI',
#         'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN',
#         'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH',
#         'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA',
#         'WV', 'WI', 'WY'],
#        dtype='object', name='abbrev')
#  FloatBlock: slice(0, 7, 1), 7 x 51, dtype: float64,
#  '_item_cache': {},
#  '_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>}

# %%
df
# Out:
#         total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# abbrev
# AL       18.8     7.332    5.640          18.048       15.040       784.55
# AK       18.1     7.421    4.525          16.290       17.014      1053.48
# AZ       18.6     6.510    5.208          15.624       17.856       899.47
# AR       22.4     4.032    5.824          21.056       21.280       827.34
# CA       12.0     4.200    3.360          10.920       10.680       878.41
# CO       13.6     5.032    3.808          10.744       12.920       835.50
# CT       10.8     4.968    3.888           9.396        8.856      1068.73
# DE       16.2     6.156    4.860          14.094       16.038      1137.87
# DC        5.9     2.006    1.593           5.900        5.900      1273.89
# FL       17.9     3.759    5.191          16.468       16.826      1160.13
# GA       15.6     2.964    3.900          14.820       14.508       913.15
# HI       17.5     9.450    7.175          14.350       15.225       861.18
# ID       15.3     5.508    4.437          13.005       14.994       641.96
# IL       12.8     4.608    4.352          12.032       12.288       803.11
# IN       14.5     3.625    4.205          13.775       13.775       710.46
# IA       15.7     2.669    3.925          15.229       13.659       649.06
# KS       17.8     4.806    4.272          13.706       15.130       780.45
# KY       21.4     4.066    4.922          16.692       16.264       872.51
# LA       20.5     7.175    6.765          14.965       20.090      1281.55
# ME       15.1     5.738    4.530          13.137       12.684       661.88
# MD       12.5     4.250    4.000           8.875       12.375      1048.78
# MA        8.2     1.886    2.870           7.134        6.560      1011.14
# MI       14.1     3.384    3.948          13.395       10.857      1110.61
# MN        9.6     2.208    2.784           8.448        8.448       777.18
# MS       17.6     2.640    5.456           1.760       17.600       896.07
# MO       16.1     6.923    5.474          14.812       13.524       790.32
# MT       21.4     8.346    9.416          17.976       18.190       816.21
# NE       14.9     1.937    5.215          13.857       13.410       732.28
# NV       14.7     5.439    4.704          13.965       14.553      1029.87
# NH       11.6     4.060    3.480          10.092        9.628       746.54
# NJ       11.2     1.792    3.136           9.632        8.736      1301.52
# NM       18.4     3.496    4.968          12.328       18.032       869.85
# NY       12.3     3.936    3.567          10.824        9.840      1234.31
# NC       16.8     6.552    5.208          15.792       13.608       708.24
# ND       23.9     5.497   10.038          23.661       20.554       688.75
# OH       14.1     3.948    4.794          13.959       11.562       697.73
# OK       19.9     6.368    5.771          18.308       18.706       881.51
# OR       12.8     4.224    3.328           8.576       11.520       804.71
# PA       18.2     9.100    5.642          17.472       16.016       905.99
# RI       11.1     3.774    4.218          10.212        8.769      1148.99
# SC       23.9     9.082    9.799          22.944       19.359       858.97
# SD       19.4     6.014    6.402          19.012       16.684       669.31
# TN       19.5     4.095    5.655          15.990       15.795       767.91
# TX       19.4     7.760    7.372          17.654       16.878      1004.75
# UT       11.3     4.859    1.808           9.944       10.848       809.38
# VT       13.6     4.080    4.080          13.056       12.920       716.20
# VA       12.7     2.413    3.429          11.049       11.176       768.95
# WA       10.6     4.452    3.498           8.692        9.116       890.03
# WV       23.8     8.092    6.664          23.086       20.706       992.61
# WI       13.8     4.968    4.554           5.382       11.592       670.31
# WY       17.4     7.308    5.568          14.094       15.660       791.14
#
#         ins_losses
# abbrev
# AL          145.08
# AK          133.93
# AZ          110.35
# AR          142.39
# CA          165.63
# CO          139.91
# CT          167.02
# DE          151.48
# DC          136.05
# FL          144.18
# GA          142.80
# HI          120.92
# ID           82.75
# IL          139.15
# IN          108.92
# IA          114.47
# KS          133.80
# KY          137.13
# LA          194.78
# ME           96.57
# MD          192.70
# MA          135.63
# MI          152.26
# MN          133.35
# MS          155.77
# MO          144.45
# MT           85.15
# NE          114.82
# NV          138.71
# NH          120.21
# NJ          159.85
# NM          120.75
# NY          150.01
# NC          127.82
# ND          109.72
# OH          133.52
# OK          178.86
# OR          104.61
# PA          153.86
# RI          148.58
# SC          116.29
# SD           96.87
# TN          155.57
# TX          156.83
# UT          109.48
# VT          109.61
# VA          153.72
# WA          111.62
# WV          152.56
# WI          106.62
# WY          122.04

# %%
model.fit(x=)
# Out:
#   File "<ipython-input-17-c774fde97e36>", line 1
#     model.fit(x=)
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Data Visualization to Analyize Patterns

# %% [markdown]
# > Choose two variables that have a relationship. For example, would the `total` number of accidents **increase** if alcohol also increases?
# > As the 2 variables are **numerical**, visualize the data with a `scatterplot()`.
# >
# > - Is there a figure that can represents the relationship between these 2 variables? Which one?

# %%
seaborn.scatterplot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-009984861ccf> in <module>
# ----> 1 seaborn.scatterplot()
#
# NameError: name 'seaborn' is not defined

# %%
import seaborn

# %%
seaborn.scatterplot(x='alcohol', y='total', data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='total'>

# %%
seaborn.scatterplot(x='no_previous', y='total', data=df)
# Out:
# <AxesSubplot:xlabel='no_previous', ylabel='total'>

# %%
df.corr()
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %% [markdown]
# ### Separate Variables for the Model
#
# > Regarding their role:
# > 1. **Target Variable `y`**
# >
# > - [ ] What would you like **to predict**?
# >
# > Total number of accients? Or Alcohol?
# >
# > 2. **Explanatory Variable `X`**
# >
# > - [ ] Which variable will you use **to explain** the target?

# %%
target=df['total']

# %%
explanatory=df[['alcohol']]

# %%
model=LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': False,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False}

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.fit(X=explanatory, y=target)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': False,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 1,
#  'coef_': array([2.0325063]),
#  '_residues': 231.96888653310063,
#  'rank_': 1,
#  'singular_': array([12.22681605]),
#  'intercept_': 5.8577761548263005}

# %% [markdown]
# ### Finally `fit()` the Model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()

# %%
model.__dict__
# Out:
# {'base_estimator': DecisionTreeRegressor(),
#  'n_estimators': 100,
#  'estimator_params': ('criterion',
#   'max_depth',
#   'min_samples_split',
#   'min_samples_leaf',
#   'min_weight_fraction_leaf',
#   'max_features',
#   'max_leaf_nodes',
#   'min_impurity_decrease',
#   'min_impurity_split',
#   'random_state',
#   'ccp_alpha'),
#  'bootstrap': True,
#  'oob_score': False,
#  'n_jobs': None,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False,
#  'class_weight': None,
#  'max_samples': None,
#  'criterion': 'mse',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'ccp_alpha': 0.0}

# %%
model.fit(X=explanatory, y=target)
# Out:
# RandomForestRegressor()

# %%
model.__dict__
# Out:
# {'base_estimator': DecisionTreeRegressor(),
#  'n_estimators': 100,
#  'estimator_params': ('criterion',
#   'max_depth',
#   'min_samples_split',
#   'min_samples_leaf',
#   'min_weight_fraction_leaf',
#   'max_features',
#   'max_leaf_nodes',
#   'min_impurity_decrease',
#   'min_impurity_split',
#   'random_state',
#   'ccp_alpha'),
#  'bootstrap': True,
#  'oob_score': False,
#  'n_jobs': None,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False,
#  'class_weight': None,
#  'max_samples': None,
#  'criterion': 'mse',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'ccp_alpha': 0.0,
#  'n_features_in_': 1,
#  'n_features_': 1,
#  'n_outputs_': 1,
#  'base_estimator_': DecisionTreeRegressor(),
#  'estimators_': [DecisionTreeRegressor(max_features='auto', random_state=582056042),
#   DecisionTreeRegressor(max_features='auto', random_state=648528929),
#   DecisionTreeRegressor(max_features='auto', random_state=1181486469),
#   DecisionTreeRegressor(max_features='auto', random_state=1310644558),
#   DecisionTreeRegressor(max_features='auto', random_state=756460498),
#   DecisionTreeRegressor(max_features='auto', random_state=272808905),
#   DecisionTreeRegressor(max_features='auto', random_state=2003938097),
#   DecisionTreeRegressor(max_features='auto', random_state=517619372),
#   DecisionTreeRegressor(max_features='auto', random_state=723405797),
#   DecisionTreeRegressor(max_features='auto', random_state=1367866591),
#   DecisionTreeRegressor(max_features='auto', random_state=352558591),
#   DecisionTreeRegressor(max_features='auto', random_state=76876548),
#   DecisionTreeRegressor(max_features='auto', random_state=2081456903),
#   DecisionTreeRegressor(max_features='auto', random_state=183234116),
#   DecisionTreeRegressor(max_features='auto', random_state=1559490770),
#   DecisionTreeRegressor(max_features='auto', random_state=1070062490),
#   DecisionTreeRegressor(max_features='auto', random_state=339339378),
#   DecisionTreeRegressor(max_features='auto', random_state=1144767958),
#   DecisionTreeRegressor(max_features='auto', random_state=943940260),
#   DecisionTreeRegressor(max_features='auto', random_state=869820048),
#   DecisionTreeRegressor(max_features='auto', random_state=1383159089),
#   DecisionTreeRegressor(max_features='auto', random_state=1927531427),
#   DecisionTreeRegressor(max_features='auto', random_state=546316577),
#   DecisionTreeRegressor(max_features='auto', random_state=83253005),
#   DecisionTreeRegressor(max_features='auto', random_state=2139858446),
#   DecisionTreeRegressor(max_features='auto', random_state=464093185),
#   DecisionTreeRegressor(max_features='auto', random_state=982950764),
#   DecisionTreeRegressor(max_features='auto', random_state=1644899174),
#   DecisionTreeRegressor(max_features='auto', random_state=2072843901),
#   DecisionTreeRegressor(max_features='auto', random_state=1474997895),
#   DecisionTreeRegressor(max_features='auto', random_state=2054597718),
#   DecisionTreeRegressor(max_features='auto', random_state=1497787670),
#   DecisionTreeRegressor(max_features='auto', random_state=2083220475),
#   DecisionTreeRegressor(max_features='auto', random_state=1211691262),
#   DecisionTreeRegressor(max_features='auto', random_state=938272138),
#   DecisionTreeRegressor(max_features='auto', random_state=1501461203),
#   DecisionTreeRegressor(max_features='auto', random_state=423678336),
#   DecisionTreeRegressor(max_features='auto', random_state=1702988177),
#   DecisionTreeRegressor(max_features='auto', random_state=1859214335),
#   DecisionTreeRegressor(max_features='auto', random_state=1216393856),
#   DecisionTreeRegressor(max_features='auto', random_state=1836603863),
#   DecisionTreeRegressor(max_features='auto', random_state=470496908),
#   DecisionTreeRegressor(max_features='auto', random_state=362864830),
#   DecisionTreeRegressor(max_features='auto', random_state=931594128),
#   DecisionTreeRegressor(max_features='auto', random_state=1956044131),
#   DecisionTreeRegressor(max_features='auto', random_state=1223637489),
#   DecisionTreeRegressor(max_features='auto', random_state=2073638164),
#   DecisionTreeRegressor(max_features='auto', random_state=2065510035),
#   DecisionTreeRegressor(max_features='auto', random_state=1690087090),
#   DecisionTreeRegressor(max_features='auto', random_state=865424135),
#   DecisionTreeRegressor(max_features='auto', random_state=2063080188),
#   DecisionTreeRegressor(max_features='auto', random_state=162595733),
#   DecisionTreeRegressor(max_features='auto', random_state=779909575),
#   DecisionTreeRegressor(max_features='auto', random_state=1477848855),
#   DecisionTreeRegressor(max_features='auto', random_state=1427357291),
#   DecisionTreeRegressor(max_features='auto', random_state=285765854),
#   DecisionTreeRegressor(max_features='auto', random_state=1556189428),
#   DecisionTreeRegressor(max_features='auto', random_state=213250836),
#   DecisionTreeRegressor(max_features='auto', random_state=1159343872),
#   DecisionTreeRegressor(max_features='auto', random_state=969141992),
#   DecisionTreeRegressor(max_features='auto', random_state=390215687),
#   DecisionTreeRegressor(max_features='auto', random_state=1084842411),
#   DecisionTreeRegressor(max_features='auto', random_state=685619099),
#   DecisionTreeRegressor(max_features='auto', random_state=1185441428),
#   DecisionTreeRegressor(max_features='auto', random_state=27638501),
#   DecisionTreeRegressor(max_features='auto', random_state=1132279479),
#   DecisionTreeRegressor(max_features='auto', random_state=1714314466),
#   DecisionTreeRegressor(max_features='auto', random_state=1288934246),
#   DecisionTreeRegressor(max_features='auto', random_state=1165028524),
#   DecisionTreeRegressor(max_features='auto', random_state=468796521),
#   DecisionTreeRegressor(max_features='auto', random_state=1880007316),
#   DecisionTreeRegressor(max_features='auto', random_state=2116264665),
#   DecisionTreeRegressor(max_features='auto', random_state=50319013),
#   DecisionTreeRegressor(max_features='auto', random_state=1465371200),
#   DecisionTreeRegressor(max_features='auto', random_state=413444662),
#   DecisionTreeRegressor(max_features='auto', random_state=2104029627),
#   DecisionTreeRegressor(max_features='auto', random_state=2027420334),
#   DecisionTreeRegressor(max_features='auto', random_state=407815996),
#   DecisionTreeRegressor(max_features='auto', random_state=1789818089),
#   DecisionTreeRegressor(max_features='auto', random_state=1042135900),
#   DecisionTreeRegressor(max_features='auto', random_state=1862361077),
#   DecisionTreeRegressor(max_features='auto', random_state=1833133632),
#   DecisionTreeRegressor(max_features='auto', random_state=287652121),
#   DecisionTreeRegressor(max_features='auto', random_state=820423512),
#   DecisionTreeRegressor(max_features='auto', random_state=1477325749),
#   DecisionTreeRegressor(max_features='auto', random_state=1976118342),
#   DecisionTreeRegressor(max_features='auto', random_state=1131508219),
#   DecisionTreeRegressor(max_features='auto', random_state=1560668674),
#   DecisionTreeRegressor(max_features='auto', random_state=1455370505),
#   DecisionTreeRegressor(max_features='auto', random_state=915720044),
#   DecisionTreeRegressor(max_features='auto', random_state=2057145315),
#   DecisionTreeRegressor(max_features='auto', random_state=235818551),
#   DecisionTreeRegressor(max_features='auto', random_state=1009555760),
#   DecisionTreeRegressor(max_features='auto', random_state=415907073),
#   DecisionTreeRegressor(max_features='auto', random_state=471528476),
#   DecisionTreeRegressor(max_features='auto', random_state=925567636),
#   DecisionTreeRegressor(max_features='auto', random_state=805809574),
#   DecisionTreeRegressor(max_features='auto', random_state=1110366323),
#   DecisionTreeRegressor(max_features='auto', random_state=1765143921),
#   DecisionTreeRegressor(max_features='auto', random_state=1803672048)]}

# %% [markdown]
# ## Model's Mathematical Equation

# %% [markdown]
# > A model is nothing more than a mathematical equation that **helps you to calculate** something. For example:
# >
# > 1. **Churn**: which is the probability for this client not to buy me anymore?
# > 2. **Credit Approval**: which is the probability for this client to pay the credit?
# > 3. **Athlete's Injury**: which is the probability for this athlete to have an injury in the next game?
# > 4. **Car Rental**: how many cars will people rent tomorrow?
# >
# > For our case: **how many accidents** the State will have (based on alcohol)?
# > - Which is the mathematical equation?

# %% [markdown]
# ## Source Code Execution

# %% [markdown]
# > - What have happened **inside the computer** to get the model equation?

# %% [markdown]
# ## Model Interpretation

# %% [markdown]
# > - How many accidents will happen for every **one unit increase in alcohol**?

# %% [markdown]
# ## Calculate a Prediction with the Model

# %% [markdown]
# > **Programming thiking:**
# >
# > - Which `function()` can we use to make a prediction?
# > - How can you answer yourself **without searching in Google**?

# %%
model.predict(df[['alcohol']])
# Out:
# array([18.729     , 16.813     , 17.44638571, 21.14      , 12.302     ,
#        13.524     , 12.663     , 17.324     ,  7.706     , 17.75748571,
#        14.247     , 18.659     , 14.921     , 14.058     , 13.689     ,
#        14.865     , 16.021     , 19.968     , 21.132     , 15.763     ,
#        13.257     ,  8.978     , 14.373     ,  9.566     , 17.337     ,
#        16.677     , 22.215     , 15.7104    , 14.55      , 11.473     ,
#        11.563     , 18.738     , 11.809     , 17.44638571, 23.565     ,
#        14.652     , 20.265     , 12.619     , 18.477     , 12.415     ,
#        23.565     , 20.547     , 19.081     , 19.229     , 10.082     ,
#        13.406     , 12.327     , 11.063     , 22.386     , 14.572     ,
#        17.887     ])

# %%
dfsel=df[['alcohol','total']].copy()

# %%
dfsel['prediccion']=model.predict(df[['alcohol']])

# %%
dfsel
# Out:
#         alcohol  total  prediccion
# abbrev
# AL        5.640   18.8   18.729000
# AK        4.525   18.1   16.813000
# AZ        5.208   18.6   17.446386
# AR        5.824   22.4   21.140000
# CA        3.360   12.0   12.302000
# CO        3.808   13.6   13.524000
# CT        3.888   10.8   12.663000
# DE        4.860   16.2   17.324000
# DC        1.593    5.9    7.706000
# FL        5.191   17.9   17.757486
# GA        3.900   15.6   14.247000
# HI        7.175   17.5   18.659000
# ID        4.437   15.3   14.921000
# IL        4.352   12.8   14.058000
# IN        4.205   14.5   13.689000
# IA        3.925   15.7   14.865000
# KS        4.272   17.8   16.021000
# KY        4.922   21.4   19.968000
# LA        6.765   20.5   21.132000
# ME        4.530   15.1   15.763000
# MD        4.000   12.5   13.257000
# MA        2.870    8.2    8.978000
# MI        3.948   14.1   14.373000
# MN        2.784    9.6    9.566000
# MS        5.456   17.6   17.337000
# MO        5.474   16.1   16.677000
# MT        9.416   21.4   22.215000
# NE        5.215   14.9   15.710400
# NV        4.704   14.7   14.550000
# NH        3.480   11.6   11.473000
# NJ        3.136   11.2   11.563000
# NM        4.968   18.4   18.738000
# NY        3.567   12.3   11.809000
# NC        5.208   16.8   17.446386
# ND       10.038   23.9   23.565000
# OH        4.794   14.1   14.652000
# OK        5.771   19.9   20.265000
# OR        3.328   12.8   12.619000
# PA        5.642   18.2   18.477000
# RI        4.218   11.1   12.415000
# SC        9.799   23.9   23.565000
# SD        6.402   19.4   20.547000
# TN        5.655   19.5   19.081000
# TX        7.372   19.4   19.229000
# UT        1.808   11.3   10.082000
# VT        4.080   13.6   13.406000
# VA        3.429   12.7   12.327000
# WA        3.498   10.6   11.063000
# WV        6.664   23.8   22.386000
# WI        4.554   13.8   14.572000
# WY        5.568   17.4   17.887000

# %%
dfsel.total-dfsel.prediccion
# Out:
# abbrev
# AL    0.071000
# AK    1.287000
# AZ    1.153614
# AR    1.260000
# CA   -0.302000
# CO    0.076000
# CT   -1.863000
# DE   -1.124000
# DC   -1.806000
# FL    0.142514
# GA    1.353000
# HI   -1.159000
# ID    0.379000
# IL   -1.258000
# IN    0.811000
# IA    0.835000
# KS    1.779000
# KY    1.432000
# LA   -0.632000
# ME   -0.663000
# MD   -0.757000
# MA   -0.778000
# MI   -0.273000
# MN    0.034000
# MS    0.263000
# MO   -0.577000
# MT   -0.815000
# NE   -0.810400
# NV    0.150000
# NH    0.127000
# NJ   -0.363000
# NM   -0.338000
# NY    0.491000
# NC   -0.646386
# ND    0.335000
# OH   -0.552000
# OK   -0.365000
# OR    0.181000
# PA   -0.277000
# RI   -1.315000
# SC    0.335000
# SD   -1.147000
# TN    0.419000
# TX    0.171000
# UT    1.218000
# VT    0.194000
# VA    0.373000
# WA   -0.463000
# WV    1.414000
# WI   -0.772000
# WY   -0.487000
# dtype: float64

# %%
dfsel['error']=dfsel.total-dfsel.prediccion

# %%
dfsel
# Out:
#         alcohol  total  prediccion     error
# abbrev
# AL        5.640   18.8   18.729000  0.071000
# AK        4.525   18.1   16.813000  1.287000
# AZ        5.208   18.6   17.446386  1.153614
# AR        5.824   22.4   21.140000  1.260000
# CA        3.360   12.0   12.302000 -0.302000
# CO        3.808   13.6   13.524000  0.076000
# CT        3.888   10.8   12.663000 -1.863000
# DE        4.860   16.2   17.324000 -1.124000
# DC        1.593    5.9    7.706000 -1.806000
# FL        5.191   17.9   17.757486  0.142514
# GA        3.900   15.6   14.247000  1.353000
# HI        7.175   17.5   18.659000 -1.159000
# ID        4.437   15.3   14.921000  0.379000
# IL        4.352   12.8   14.058000 -1.258000
# IN        4.205   14.5   13.689000  0.811000
# IA        3.925   15.7   14.865000  0.835000
# KS        4.272   17.8   16.021000  1.779000
# KY        4.922   21.4   19.968000  1.432000
# LA        6.765   20.5   21.132000 -0.632000
# ME        4.530   15.1   15.763000 -0.663000
# MD        4.000   12.5   13.257000 -0.757000
# MA        2.870    8.2    8.978000 -0.778000
# MI        3.948   14.1   14.373000 -0.273000
# MN        2.784    9.6    9.566000  0.034000
# MS        5.456   17.6   17.337000  0.263000
# MO        5.474   16.1   16.677000 -0.577000
# MT        9.416   21.4   22.215000 -0.815000
# NE        5.215   14.9   15.710400 -0.810400
# NV        4.704   14.7   14.550000  0.150000
# NH        3.480   11.6   11.473000  0.127000
# NJ        3.136   11.2   11.563000 -0.363000
# NM        4.968   18.4   18.738000 -0.338000
# NY        3.567   12.3   11.809000  0.491000
# NC        5.208   16.8   17.446386 -0.646386
# ND       10.038   23.9   23.565000  0.335000
# OH        4.794   14.1   14.652000 -0.552000
# OK        5.771   19.9   20.265000 -0.365000
# OR        3.328   12.8   12.619000  0.181000
# PA        5.642   18.2   18.477000 -0.277000
# RI        4.218   11.1   12.415000 -1.315000
# SC        9.799   23.9   23.565000  0.335000
# SD        6.402   19.4   20.547000 -1.147000
# TN        5.655   19.5   19.081000  0.419000
# TX        7.372   19.4   19.229000  0.171000
# UT        1.808   11.3   10.082000  1.218000
# VT        4.080   13.6   13.406000  0.194000
# VA        3.429   12.7   12.327000  0.373000
# WA        3.498   10.6   11.063000 -0.463000
# WV        6.664   23.8   22.386000  1.414000
# WI        4.554   13.8   14.572000 -0.772000
# WY        5.568   17.4   17.887000 -0.487000

# %%
dfsel.error**2
# Out:
# abbrev
# AL    0.005041
# AK    1.656369
# AZ    1.330826
# AR    1.587600
# CA    0.091204
# CO    0.005776
# CT    3.470769
# DE    1.263376
# DC    3.261636
# FL    0.020310
# GA    1.830609
# HI    1.343281
# ID    0.143641
# IL    1.582564
# IN    0.657721
# IA    0.697225
# KS    3.164841
# KY    2.050624
# LA    0.399424
# ME    0.439569
# MD    0.573049
# MA    0.605284
# MI    0.074529
# MN    0.001156
# MS    0.069169
# MO    0.332929
# MT    0.664225
# NE    0.656748
# NV    0.022500
# NH    0.016129
# NJ    0.131769
# NM    0.114244
# NY    0.241081
# NC    0.417814
# ND    0.112225
# OH    0.304704
# OK    0.133225
# OR    0.032761
# PA    0.076729
# RI    1.729225
# SC    0.112225
# SD    1.315609
# TN    0.175561
# TX    0.029241
# UT    1.483524
# VT    0.037636
# VA    0.139129
# WA    0.214369
# WV    1.999396
# WI    0.595984
# WY    0.237169
# Name: error, dtype: float64

# %%
dfsel['error2']=dfsel.error**2

# %%
dfsel
# Out:
#         alcohol  total  prediccion     error    error2
# abbrev
# AL        5.640   18.8   18.729000  0.071000  0.005041
# AK        4.525   18.1   16.813000  1.287000  1.656369
# AZ        5.208   18.6   17.446386  1.153614  1.330826
# AR        5.824   22.4   21.140000  1.260000  1.587600
# CA        3.360   12.0   12.302000 -0.302000  0.091204
# CO        3.808   13.6   13.524000  0.076000  0.005776
# CT        3.888   10.8   12.663000 -1.863000  3.470769
# DE        4.860   16.2   17.324000 -1.124000  1.263376
# DC        1.593    5.9    7.706000 -1.806000  3.261636
# FL        5.191   17.9   17.757486  0.142514  0.020310
# GA        3.900   15.6   14.247000  1.353000  1.830609
# HI        7.175   17.5   18.659000 -1.159000  1.343281
# ID        4.437   15.3   14.921000  0.379000  0.143641
# IL        4.352   12.8   14.058000 -1.258000  1.582564
# IN        4.205   14.5   13.689000  0.811000  0.657721
# IA        3.925   15.7   14.865000  0.835000  0.697225
# KS        4.272   17.8   16.021000  1.779000  3.164841
# KY        4.922   21.4   19.968000  1.432000  2.050624
# LA        6.765   20.5   21.132000 -0.632000  0.399424
# ME        4.530   15.1   15.763000 -0.663000  0.439569
# MD        4.000   12.5   13.257000 -0.757000  0.573049
# MA        2.870    8.2    8.978000 -0.778000  0.605284
# MI        3.948   14.1   14.373000 -0.273000  0.074529
# MN        2.784    9.6    9.566000  0.034000  0.001156
# MS        5.456   17.6   17.337000  0.263000  0.069169
# MO        5.474   16.1   16.677000 -0.577000  0.332929
# MT        9.416   21.4   22.215000 -0.815000  0.664225
# NE        5.215   14.9   15.710400 -0.810400  0.656748
# NV        4.704   14.7   14.550000  0.150000  0.022500
# NH        3.480   11.6   11.473000  0.127000  0.016129
# NJ        3.136   11.2   11.563000 -0.363000  0.131769
# NM        4.968   18.4   18.738000 -0.338000  0.114244
# NY        3.567   12.3   11.809000  0.491000  0.241081
# NC        5.208   16.8   17.446386 -0.646386  0.417814
# ND       10.038   23.9   23.565000  0.335000  0.112225
# OH        4.794   14.1   14.652000 -0.552000  0.304704
# OK        5.771   19.9   20.265000 -0.365000  0.133225
# OR        3.328   12.8   12.619000  0.181000  0.032761
# PA        5.642   18.2   18.477000 -0.277000  0.076729
# RI        4.218   11.1   12.415000 -1.315000  1.729225
# SC        9.799   23.9   23.565000  0.335000  0.112225
# SD        6.402   19.4   20.547000 -1.147000  1.315609
# TN        5.655   19.5   19.081000  0.419000  0.175561
# TX        7.372   19.4   19.229000  0.171000  0.029241
# UT        1.808   11.3   10.082000  1.218000  1.483524
# VT        4.080   13.6   13.406000  0.194000  0.037636
# VA        3.429   12.7   12.327000  0.373000  0.139129
# WA        3.498   10.6   11.063000 -0.463000  0.214369
# WV        6.664   23.8   22.386000  1.414000  1.999396
# WI        4.554   13.8   14.572000 -0.772000  0.595984
# WY        5.568   17.4   17.887000 -0.487000  0.237169

# %%
rss=dfsel.error2.sum()

# %%
rss
# Out:
# 37.65174489346951

# %%
tss=((dfsel.total-dfsel.total.mean())**2).sum()

# %%
tss
# Out:
# 849.5450980392156

# %%
1-rss/tss
# Out:
# 0.9556801104728033

# %%
model.score(X=explanatory,y=target)
# Out:
# 0.9556801104728033

# %% [markdown]
# ## Model Visualization

# %% [markdown]
# > 1. What would happend if you **plot the predictions**?
# > 2. And the **real data**?

# %% [markdown]
# # How good is my model? **Goodness of Fit**

# %% [markdown]
# > - How can we compare **reality vs. predictions**?

# %% [markdown]
# # Other Regression Models to Calculate Accidents

# %% [markdown]
# > Tutorial → [Why All Machine Learning Models Are the Same](https://blogsotastico.com/why-all-machine-learning-models-are-the-same)

# %% [markdown]
# ## `RandomForestRegression()`

# %% [markdown]
# ## `SVR()`

# %% [markdown]
# # Visualize & Choose the Best Model

# %% [markdown]
# > - Which model is the best?
# > - Is there any **metric to compare** these models?
# > - Which is the metric?
# > - Get the metric for each model
